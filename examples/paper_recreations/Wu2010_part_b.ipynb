# %% [markdown]
# # Example: Regenerating Data from
# # [R. Wu et al. / Elec Acta 54 25 (2010) 7394–7403](http://www.sciencedirect.com/science/article/pii/S0013468610009503)

# %% [markdown]
# Import the modules

# %%
import openpnm as op
import matplotlib.pyplot as plt
import scipy as sp
import numpy as np
import openpnm.models.geometry as gm
import openpnm.topotools as tt
# %matplotlib inline
# Out:
# C:\Users\Tom\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Set the workspace loglevel to not print anything

# %%
wrk = op.Workspace()
wrk.loglevel=50

# %%
# %run shared_funcs.ipynb

# %% [markdown]
# We can run multiple times as the network sizes are randomly generated between a given range we can obtain an average

# %%
x_values = []
y_values = []

for ensemble in range(10):
    x_ensemble, y_ensemble = simulation(n=8)
    x_values.append(x_ensemble)
    y_values.append(y_ensemble)
# Out:
# ************************************************************
# Running Sim with Net Size = 8 num points 51
# ************************************************************
# Step 0 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 89.50674700767024
# Solution converged: 0.0
# Step 0 Saturation 0.000 Diffusivity 0.094
# Step 1 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 89.50674700767024
# Solution converged: 0.0
# Step 1 Saturation 0.000 Diffusivity 0.094
# Step 2 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 89.50674700767024
# Solution converged: 0.0
# Step 2 Saturation 0.000 Diffusivity 0.094
# Step 3 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 90.04136874177979
# Solution converged: 0.0
# Step 3 Saturation 0.012 Diffusivity 0.093
# Step 4 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 90.09558055843621
# Solution converged: 0.0
# Step 4 Saturation 0.014 Diffusivity 0.093
# Step 5 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 91.1672487169285
# Solution converged: 0.0
# Step 5 Saturation 0.027 Diffusivity 0.091
# Step 6 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 94.4508277773252
# Solution converged: 0.0
# Step 6 Saturation 0.047 Diffusivity 0.085
# Step 7 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 94.79342315697662
# Solution converged: 0.0
# Step 7 Saturation 0.059 Diffusivity 0.084
# Step 8 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 98.72333586119235
# Solution converged: 0.0
# Step 8 Saturation 0.092 Diffusivity 0.077
# Step 9 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 99.64947697639937
# Solution converged: 0.0
# Step 9 Saturation 0.100 Diffusivity 0.076
# Step 10 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 109.15363387964052
# Solution converged: 0.0
# Step 10 Saturation 0.141 Diffusivity 0.058
# Step 11 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 109.49505744122766
# Solution converged: 0.0
# Step 11 Saturation 0.180 Diffusivity 0.051
# Step 12 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 115.16927831636482
# Solution converged: 0.0
# Step 12 Saturation 0.219 Diffusivity 0.039
# Step 13 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 117.8409249038869
# Solution converged: 0.0
# Step 13 Saturation 0.258 Diffusivity 0.032
# Step 14 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 121.99084726013976
# Solution converged: 0.0
# Step 14 Saturation 0.297 Diffusivity 0.024
# Step 15 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 120.98291173008842
# Solution converged: 0.0
# Step 15 Saturation 0.332 Diffusivity 0.019
# Step 16 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 120.98323912327443
# Solution converged: 0.0
# Step 16 Saturation 0.371 Diffusivity 0.007
# Step 17 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 123.27450545504918
# Solution converged: 0.0
# Step 17 Saturation 0.408 Diffusivity 0.005
# Step 18 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 122.18292185253331
# Solution converged: 0.0
# Step 18 Saturation 0.443 Diffusivity 0.005
# Step 19 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 122.04216583711198
# Solution converged: 0.0
# Step 19 Saturation 0.465 Diffusivity 0.005
# Step 20 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 121.4354090085807
# Solution converged: 0.0
# Step 20 Saturation 0.492 Diffusivity 0.005
# Step 21 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 120.4235286153219
# Solution converged: 0.0
# Step 21 Saturation 0.527 Diffusivity 0.005
# Step 22 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 117.93729566988762
# Solution converged: 0.0
# Step 22 Saturation 0.566 Diffusivity 0.004
# Step 23 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 113.7278124044087
# Solution converged: 0.0
# Step 23 Saturation 0.605 Diffusivity 0.003
# Step 24 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 98.5095070475367
# Solution converged: 0.0
# Step 24 Saturation 0.633 Diffusivity 0.002
# Step 25 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 98.5095070475367
# Solution converged: 0.0
# Step 25 Saturation 0.633 Diffusivity 0.002
# Step 26 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 98.5095070475367
# Solution converged: 0.0
# Step 26 Saturation 0.633 Diffusivity 0.002
# Step 27 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 98.46637626833831
# Solution converged: 0.0
# Step 27 Saturation 0.645 Diffusivity 0.002
# Step 28 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 86.52732046776158
# Solution converged: 0.0
# Step 28 Saturation 0.666 Diffusivity 0.001
# Step 29 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 86.52732046776158
# Solution converged: 0.0
# Step 29 Saturation 0.666 Diffusivity 0.001
# Step 30 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 86.2530438239777
# Solution converged: 0.0
# Step 30 Saturation 0.678 Diffusivity 0.001
# Step 31 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 86.2530438239777
# Solution converged: 0.0
# Step 31 Saturation 0.678 Diffusivity 0.001
# Step 32 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 82.18861453763509
# Solution converged: 0.0
# Step 32 Saturation 0.701 Diffusivity 0.000
# Step 33 is NOT percolating
# Step 33 Saturation 0.721 Diffusivity 0.000
# Step 34 is NOT percolating
# Step 34 Saturation 0.744 Diffusivity 0.000
# Step 35 is NOT percolating
# Step 35 Saturation 0.771 Diffusivity 0.000
# Step 36 is NOT percolating
# Step 36 Saturation 0.787 Diffusivity 0.000
# Step 37 is NOT percolating
# Step 37 Saturation 0.803 Diffusivity 0.000
# Step 38 is NOT percolating
# Step 38 Saturation 0.832 Diffusivity 0.000
# Step 39 is NOT percolating
# Step 39 Saturation 0.842 Diffusivity 0.000
# Step 40 is NOT percolating
# Step 40 Saturation 0.852 Diffusivity 0.000
# Step 41 is NOT percolating
# Step 41 Saturation 0.875 Diffusivity 0.000
# Step 42 is NOT percolating
# Step 42 Saturation 0.893 Diffusivity 0.000
# Step 43 is NOT percolating
# Step 43 Saturation 0.912 Diffusivity 0.000
# Step 44 is NOT percolating
# Step 44 Saturation 0.920 Diffusivity 0.000
# Step 45 is NOT percolating
# Step 45 Saturation 0.939 Diffusivity 0.000
# Step 46 is NOT percolating
# Step 46 Saturation 0.961 Diffusivity 0.000
# Step 47 is NOT percolating
# Step 47 Saturation 0.982 Diffusivity 0.000
# Step 48 is NOT percolating
# Step 48 Saturation 1.000 Diffusivity 0.000
# Step 49 is NOT percolating
# Step 49 Saturation 1.000 Diffusivity 0.000
# Step 50 is NOT percolating
# Step 50 Saturation 1.000 Diffusivity 0.000
# ************************************************************
# Running Sim with Net Size = 8 num points 51
# ************************************************************
# Step 0 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 88.1394681311782
# Solution converged: 0.0
# Step 0 Saturation 0.000 Diffusivity 0.094
# Step 1 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 88.1394681311782
# Solution converged: 0.0
# Step 1 Saturation 0.000 Diffusivity 0.094
# Step 2 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 88.1394681311782
# Solution converged: 0.0
# Step 2 Saturation 0.000 Diffusivity 0.094
# Step 3 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 88.58536051413418
# Solution converged: 0.0
# Step 3 Saturation 0.008 Diffusivity 0.093
# Step 4 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 88.58536051413418
# Solution converged: 0.0
# Step 4 Saturation 0.008 Diffusivity 0.093
# Step 5 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 90.00562961494694
# Solution converged: 0.0
# Step 5 Saturation 0.023 Diffusivity 0.090
# Step 6 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 91.76325973768824
# Solution converged: 0.0
# Step 6 Saturation 0.047 Diffusivity 0.085
# Step 7 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 94.69148134921944
# Solution converged: 0.0
# Step 7 Saturation 0.082 Diffusivity 0.078
# Step 8 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 97.06894799679733
# Solution converged: 0.0
# Step 8 Saturation 0.109 Diffusivity 0.073
# Step 9 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 102.48184491195431
# Solution converged: 0.0
# Step 9 Saturation 0.143 Diffusivity 0.063
# Step 10 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 102.80227892191957
# Solution converged: 0.0
# Step 10 Saturation 0.176 Diffusivity 0.059
# Step 11 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 110.03555559721082
# Solution converged: 0.0
# Step 11 Saturation 0.211 Diffusivity 0.047
# Step 12 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 112.15341732980937
# Solution converged: 0.0
# Step 12 Saturation 0.250 Diffusivity 0.036
# Step 13 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 111.90203089548427
# Solution converged: 0.0
# Step 13 Saturation 0.289 Diffusivity 0.031
# Step 14 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 110.37446289121598
# Solution converged: 0.0
# Step 14 Saturation 0.328 Diffusivity 0.026
# Step 15 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 110.47641432979063
# Solution converged: 0.0
# Step 15 Saturation 0.369 Diffusivity 0.020
# Step 16 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 111.5093327212683
# Solution converged: 0.0
# Step 16 Saturation 0.408 Diffusivity 0.018
# Step 17 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 111.5093327212683
# Solution converged: 0.0
# Step 17 Saturation 0.410 Diffusivity 0.018
# Step 18 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 111.50780021855624
# Solution converged: 0.0
# Step 18 Saturation 0.412 Diffusivity 0.018
# Step 19 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 111.46388049124988
# Solution converged: 0.0
# Step 19 Saturation 0.414 Diffusivity 0.018
# Step 20 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 111.27519654061638
# Solution converged: 0.0
# Step 20 Saturation 0.422 Diffusivity 0.018
# Step 21 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 111.20069556518146
# Solution converged: 0.0
# Step 21 Saturation 0.424 Diffusivity 0.018
# Step 22 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 110.60057572647759
# Solution converged: 0.0
# Step 22 Saturation 0.439 Diffusivity 0.017
# Step 23 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 109.11251504029178
# Solution converged: 0.0
# Step 23 Saturation 0.463 Diffusivity 0.017
# Step 24 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 108.27265924799963
# Solution converged: 0.0
# Step 24 Saturation 0.473 Diffusivity 0.017
# Step 25 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 106.62257566912473
# Solution converged: 0.0
# Step 25 Saturation 0.480 Diffusivity 0.017
# Step 26 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 102.63618220784477
# Solution converged: 0.0
# Step 26 Saturation 0.500 Diffusivity 0.016
# Step 27 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 97.73759981354618
# Solution converged: 0.0
# Step 27 Saturation 0.539 Diffusivity 0.014
# Step 28 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 88.81569059742577
# Solution converged: 0.0
# Step 28 Saturation 0.568 Diffusivity 0.013
# Step 29 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 90.95187195545414
# Solution converged: 0.0
# Step 29 Saturation 0.602 Diffusivity 0.012
# Step 30 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 91.78407781432044
# Solution converged: 0.0
# Step 30 Saturation 0.615 Diffusivity 0.012
# Step 31 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 83.96626310047759
# Solution converged: 0.0
# Step 31 Saturation 0.648 Diffusivity 0.007
# Step 32 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 81.60212025868506
# Solution converged: 0.0
# Step 32 Saturation 0.688 Diffusivity 0.004
# Step 33 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 82.23939414104406
# Solution converged: 0.0
# Step 33 Saturation 0.713 Diffusivity 0.003
# Step 34 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 83.19197852646965
# Solution converged: 0.0
# Step 34 Saturation 0.748 Diffusivity 0.002
# Step 35 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 74.67069121432837
# Solution converged: 0.0
# Step 35 Saturation 0.773 Diffusivity 0.002
# Step 36 is NOT percolating
# Step 36 Saturation 0.793 Diffusivity 0.000
# Step 37 is NOT percolating
# Step 37 Saturation 0.811 Diffusivity 0.000
# Step 38 is NOT percolating
# Step 38 Saturation 0.836 Diffusivity 0.000
# Step 39 is NOT percolating
# Step 39 Saturation 0.850 Diffusivity 0.000
# Step 40 is NOT percolating
# Step 40 Saturation 0.852 Diffusivity 0.000
# Step 41 is NOT percolating
# Step 41 Saturation 0.869 Diffusivity 0.000
# Step 42 is NOT percolating
# Step 42 Saturation 0.877 Diffusivity 0.000
# Step 43 is NOT percolating
# Step 43 Saturation 0.896 Diffusivity 0.000
# Step 44 is NOT percolating
# Step 44 Saturation 0.924 Diffusivity 0.000
# Step 45 is NOT percolating
# Step 45 Saturation 0.947 Diffusivity 0.000
# Step 46 is NOT percolating
# Step 46 Saturation 0.965 Diffusivity 0.000
# Step 47 is NOT percolating
# Step 47 Saturation 0.984 Diffusivity 0.000
# Step 48 is NOT percolating
# Step 48 Saturation 1.000 Diffusivity 0.000
# Step 49 is NOT percolating
# Step 49 Saturation 1.000 Diffusivity 0.000
# Step 50 is NOT percolating
# Step 50 Saturation 1.000 Diffusivity 0.000
# ************************************************************
# Running Sim with Net Size = 8 num points 51
# ************************************************************
# Step 0 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 91.72288840239071
# Solution converged: 0.0
# Step 0 Saturation 0.000 Diffusivity 0.089
# Step 1 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 91.76498761743238
# Solution converged: 0.0
# Step 1 Saturation 0.002 Diffusivity 0.089
# Step 2 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 91.76498761743238
# Solution converged: 0.0
# Step 2 Saturation 0.002 Diffusivity 0.089
# Step 3 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 92.42027693631309
# Solution converged: 0.0
# Step 3 Saturation 0.012 Diffusivity 0.087
# Step 4 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 95.59231237270309
# Solution converged: 0.0
# Step 4 Saturation 0.049 Diffusivity 0.079
# Step 5 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 99.0253151984636
# Solution converged: 0.0
# Step 5 Saturation 0.072 Diffusivity 0.072
# Step 6 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 99.78817993752475
# Solution converged: 0.0
# Step 6 Saturation 0.105 Diffusivity 0.064
# Step 7 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 101.32659378885845
# Solution converged: 0.0
# Step 7 Saturation 0.129 Diffusivity 0.062
# Step 8 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 106.43457040850454
# Solution converged: 0.0
# Step 8 Saturation 0.166 Diffusivity 0.052
# Step 9 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 106.87627769270277
# Solution converged: 0.0
# Step 9 Saturation 0.188 Diffusivity 0.050
# Step 10 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 106.70402305700794
# Solution converged: 0.0
# Step 10 Saturation 0.227 Diffusivity 0.043
# Step 11 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 105.56694832581563
# Solution converged: 0.0
# Step 11 Saturation 0.244 Diffusivity 0.042
# Step 12 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 104.46189304494256
# Solution converged: 0.0
# Step 12 Saturation 0.277 Diffusivity 0.034
# Step 13 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 104.8537061721873
# Solution converged: 0.0
# Step 13 Saturation 0.316 Diffusivity 0.025
# Step 14 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 108.35907177281905
# Solution converged: 0.0
# Step 14 Saturation 0.355 Diffusivity 0.018
# Step 15 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 109.41787060857538
# Solution converged: 0.0
# Step 15 Saturation 0.391 Diffusivity 0.017
# Step 16 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 104.68218925597832
# Solution converged: 0.0
# Step 16 Saturation 0.420 Diffusivity 0.014
# Step 17 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 103.0849546553365
# Solution converged: 0.0
# Step 17 Saturation 0.439 Diffusivity 0.010
# Step 18 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 103.03302559603121
# Solution converged: 0.0
# Step 18 Saturation 0.455 Diffusivity 0.010
# Step 19 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 103.03302559603121
# Solution converged: 0.0
# Step 19 Saturation 0.463 Diffusivity 0.010
# Step 20 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 102.9614407979582
# Solution converged: 0.0
# Step 20 Saturation 0.465 Diffusivity 0.010
# Step 21 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 102.1352945640117
# Solution converged: 0.0
# Step 21 Saturation 0.488 Diffusivity 0.009
# Step 22 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 100.65011446645025
# Solution converged: 0.0
# Step 22 Saturation 0.498 Diffusivity 0.009
# Step 23 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 98.65902684542105
# Solution converged: 0.0
# Step 23 Saturation 0.516 Diffusivity 0.009
# Step 24 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 99.4674626390239
# Solution converged: 0.0
# Step 24 Saturation 0.539 Diffusivity 0.008
# Step 25 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 110.53813797519459
# Solution converged: 0.0
# Step 25 Saturation 0.576 Diffusivity 0.006
# Step 26 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 120.4753802119269
# Solution converged: 0.0
# Step 26 Saturation 0.615 Diffusivity 0.001
# Step 27 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 121.64472954442584
# Solution converged: 0.0
# Step 27 Saturation 0.646 Diffusivity 0.000
# Step 28 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 110.01601979401346
# Solution converged: 0.0
# Step 28 Saturation 0.684 Diffusivity 0.000
# Step 29 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 109.77500143518101
# Solution converged: 0.0
# Step 29 Saturation 0.703 Diffusivity 0.000
# Step 30 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 107.33123073297132
# Solution converged: 0.0
# Step 30 Saturation 0.717 Diffusivity 0.000
# Step 31 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 107.36825859527161
# Solution converged: 0.0
# Step 31 Saturation 0.734 Diffusivity 0.000
# Step 32 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 107.36112807098581
# Solution converged: 0.0
# Step 32 Saturation 0.736 Diffusivity 0.000
# Step 33 is NOT percolating
# Step 33 Saturation 0.768 Diffusivity 0.000
# Step 34 is NOT percolating
# Step 34 Saturation 0.777 Diffusivity 0.000
# Step 35 is NOT percolating
# Step 35 Saturation 0.777 Diffusivity 0.000
# Step 36 is NOT percolating
# Step 36 Saturation 0.789 Diffusivity 0.000
# Step 37 is NOT percolating
# Step 37 Saturation 0.812 Diffusivity 0.000
# Step 38 is NOT percolating
# Step 38 Saturation 0.832 Diffusivity 0.000
# Step 39 is NOT percolating
# Step 39 Saturation 0.850 Diffusivity 0.000
# Step 40 is NOT percolating
# Step 40 Saturation 0.859 Diffusivity 0.000
# Step 41 is NOT percolating
# Step 41 Saturation 0.865 Diffusivity 0.000
# Step 42 is NOT percolating
# Step 42 Saturation 0.875 Diffusivity 0.000
# Step 43 is NOT percolating
# Step 43 Saturation 0.889 Diffusivity 0.000
# Step 44 is NOT percolating
# Step 44 Saturation 0.914 Diffusivity 0.000
# Step 45 is NOT percolating
# Step 45 Saturation 0.934 Diffusivity 0.000
# Step 46 is NOT percolating
# Step 46 Saturation 0.955 Diffusivity 0.000
# Step 47 is NOT percolating
# Step 47 Saturation 0.982 Diffusivity 0.000
# Step 48 is NOT percolating
# Step 48 Saturation 1.000 Diffusivity 0.000
# Step 49 is NOT percolating
# Step 49 Saturation 1.000 Diffusivity 0.000
# Step 50 is NOT percolating
# Step 50 Saturation 1.000 Diffusivity 0.000
# ************************************************************
# Running Sim with Net Size = 8 num points 51
# ************************************************************
# Step 0 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 89.8439641130559
# Solution converged: 0.0
# Step 0 Saturation 0.000 Diffusivity 0.095
# Step 1 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 89.8439641130559
# Solution converged: 0.0
# Step 1 Saturation 0.000 Diffusivity 0.095
# Step 2 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 89.87551383377846
# Solution converged: 0.0
# Step 2 Saturation 0.004 Diffusivity 0.095
# Step 3 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 89.87551383377846
# Solution converged: 0.0
# Step 3 Saturation 0.004 Diffusivity 0.095
# Step 4 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 90.49902869826751
# Solution converged: 0.0
# Step 4 Saturation 0.010 Diffusivity 0.094
# Step 5 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 92.38746039727432
# Solution converged: 0.0
# Step 5 Saturation 0.033 Diffusivity 0.091
# Step 6 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 95.95013270973197
# Solution converged: 0.0
# Step 6 Saturation 0.068 Diffusivity 0.083
# Step 7 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 99.51603476415607
# Solution converged: 0.0
# Step 7 Saturation 0.104 Diffusivity 0.073
# Step 8 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 103.12837732257316
# Solution converged: 0.0
# Step 8 Saturation 0.123 Diffusivity 0.069
# Step 9 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 108.32153724642572
# Solution converged: 0.0
# Step 9 Saturation 0.162 Diffusivity 0.059
# Step 10 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 120.3792744320765
# Solution converged: 0.0
# Step 10 Saturation 0.199 Diffusivity 0.039
# Step 11 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 125.79434228135352
# Solution converged: 0.0
# Step 11 Saturation 0.238 Diffusivity 0.027
# Step 12 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 129.34145122116539
# Solution converged: 0.0
# Step 12 Saturation 0.277 Diffusivity 0.019
# Step 13 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 130.24547240740907
# Solution converged: 0.0
# Step 13 Saturation 0.316 Diffusivity 0.013
# Step 14 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 125.86528754901742
# Solution converged: 0.0
# Step 14 Saturation 0.355 Diffusivity 0.007
# Step 15 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 124.76303649802439
# Solution converged: 0.0
# Step 15 Saturation 0.396 Diffusivity 0.006
# Step 16 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 123.5590729025705
# Solution converged: 0.0
# Step 16 Saturation 0.436 Diffusivity 0.006
# Step 17 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 120.45761046978674
# Solution converged: 0.0
# Step 17 Saturation 0.475 Diffusivity 0.006
# Step 18 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 117.20596177754592
# Solution converged: 0.0
# Step 18 Saturation 0.514 Diffusivity 0.005
# Step 19 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 117.51190988483395
# Solution converged: 0.0
# Step 19 Saturation 0.535 Diffusivity 0.005
# Step 20 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 122.17835600370233
# Solution converged: 0.0
# Step 20 Saturation 0.572 Diffusivity 0.004
# Step 21 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 119.44522078172012
# Solution converged: 0.0
# Step 21 Saturation 0.584 Diffusivity 0.004
# Step 22 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 118.01139117330641
# Solution converged: 0.0
# Step 22 Saturation 0.613 Diffusivity 0.004
# Step 23 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 113.8601741750836
# Solution converged: 0.0
# Step 23 Saturation 0.646 Diffusivity 0.003
# Step 24 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 107.16269162900659
# Solution converged: 0.0
# Step 24 Saturation 0.682 Diffusivity 0.003
# Step 25 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 107.16269162900659
# Solution converged: 0.0
# Step 25 Saturation 0.688 Diffusivity 0.003
# Step 26 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 107.08197460166063
# Solution converged: 0.0
# Step 26 Saturation 0.709 Diffusivity 0.003
# Step 27 is NOT percolating
# Step 27 Saturation 0.729 Diffusivity 0.000
# Step 28 is NOT percolating
# Step 28 Saturation 0.729 Diffusivity 0.000
# Step 29 is NOT percolating
# Step 29 Saturation 0.729 Diffusivity 0.000
# Step 30 is NOT percolating
# Step 30 Saturation 0.730 Diffusivity 0.000
# Step 31 is NOT percolating
# Step 31 Saturation 0.730 Diffusivity 0.000
# Step 32 is NOT percolating
# Step 32 Saturation 0.744 Diffusivity 0.000
# Step 33 is NOT percolating
# Step 33 Saturation 0.748 Diffusivity 0.000
# Step 34 is NOT percolating
# Step 34 Saturation 0.754 Diffusivity 0.000
# Step 35 is NOT percolating
# Step 35 Saturation 0.773 Diffusivity 0.000
# Step 36 is NOT percolating
# Step 36 Saturation 0.801 Diffusivity 0.000
# Step 37 is NOT percolating
# Step 37 Saturation 0.818 Diffusivity 0.000
# Step 38 is NOT percolating
# Step 38 Saturation 0.834 Diffusivity 0.000
# Step 39 is NOT percolating
# Step 39 Saturation 0.859 Diffusivity 0.000
# Step 40 is NOT percolating
# Step 40 Saturation 0.881 Diffusivity 0.000
# Step 41 is NOT percolating
# Step 41 Saturation 0.889 Diffusivity 0.000
# Step 42 is NOT percolating
# Step 42 Saturation 0.906 Diffusivity 0.000
# Step 43 is NOT percolating
# Step 43 Saturation 0.928 Diffusivity 0.000
# Step 44 is NOT percolating
# Step 44 Saturation 0.934 Diffusivity 0.000
# Step 45 is NOT percolating
# Step 45 Saturation 0.939 Diffusivity 0.000
# Step 46 is NOT percolating
# Step 46 Saturation 0.957 Diffusivity 0.000
# Step 47 is NOT percolating
# Step 47 Saturation 0.982 Diffusivity 0.000
# Step 48 is NOT percolating
# Step 48 Saturation 1.000 Diffusivity 0.000
# Step 49 is NOT percolating
# Step 49 Saturation 1.000 Diffusivity 0.000
# Step 50 is NOT percolating
# Step 50 Saturation 1.000 Diffusivity 0.000
# ************************************************************
# Running Sim with Net Size = 8 num points 51
# ************************************************************
# Step 0 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 88.56675625646818
# Solution converged: 0.0
# Step 0 Saturation 0.000 Diffusivity 0.094
# Step 1 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 88.56675625646818
# Solution converged: 0.0
# Step 1 Saturation 0.000 Diffusivity 0.094
# Step 2 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 89.50759750555082
# Solution converged: 0.0
# Step 2 Saturation 0.008 Diffusivity 0.092
# Step 3 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 92.35669603868149
# Solution converged: 0.0
# Step 3 Saturation 0.041 Diffusivity 0.084
# Step 4 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 92.68278398910083
# Solution converged: 0.0
# Step 4 Saturation 0.047 Diffusivity 0.084
# Step 5 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 90.837631335923
# Solution converged: 0.0
# Step 5 Saturation 0.076 Diffusivity 0.080
# Step 6 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 95.75523081849049
# Solution converged: 0.0
# Step 6 Saturation 0.105 Diffusivity 0.074
# Step 7 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 96.65908287284864
# Solution converged: 0.0
# Step 7 Saturation 0.123 Diffusivity 0.072
# Step 8 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 98.5188706897033
# Solution converged: 0.0
# Step 8 Saturation 0.158 Diffusivity 0.064
# Step 9 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 101.09039821451715
# Solution converged: 0.0
# Step 9 Saturation 0.197 Diffusivity 0.050
# Step 10 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 103.32119039896233
# Solution converged: 0.0
# Step 10 Saturation 0.234 Diffusivity 0.044
# Step 11 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 105.0864298508439
# Solution converged: 0.0
# Step 11 Saturation 0.273 Diffusivity 0.035
# Step 12 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 108.06119170979547
# Solution converged: 0.0
# Step 12 Saturation 0.295 Diffusivity 0.032
# Step 13 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 107.74521336297973
# Solution converged: 0.0
# Step 13 Saturation 0.318 Diffusivity 0.029
# Step 14 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 105.3991372196012
# Solution converged: 0.0
# Step 14 Saturation 0.357 Diffusivity 0.025
# Step 15 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 102.13089705042339
# Solution converged: 0.0
# Step 15 Saturation 0.395 Diffusivity 0.023
# Step 16 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 100.93532524882187
# Solution converged: 0.0
# Step 16 Saturation 0.432 Diffusivity 0.021
# Step 17 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 102.82717308916753
# Solution converged: 0.0
# Step 17 Saturation 0.438 Diffusivity 0.021
# Step 18 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 102.9349395921534
# Solution converged: 0.0
# Step 18 Saturation 0.447 Diffusivity 0.021
# Step 19 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 102.9349395921534
# Solution converged: 0.0
# Step 19 Saturation 0.447 Diffusivity 0.021
# Step 20 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 102.9349395921534
# Solution converged: 0.0
# Step 20 Saturation 0.447 Diffusivity 0.021
# Step 21 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 102.9349395921534
# Solution converged: 0.0
# Step 21 Saturation 0.449 Diffusivity 0.021
# Step 22 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 108.64629634093868
# Solution converged: 0.0
# Step 22 Saturation 0.467 Diffusivity 0.014
# Step 23 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 116.320919449624
# Solution converged: 0.0
# Step 23 Saturation 0.490 Diffusivity 0.011
# Step 24 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 115.3241004581094
# Solution converged: 0.0
# Step 24 Saturation 0.506 Diffusivity 0.011
# Step 25 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 113.23077174646232
# Solution converged: 0.0
# Step 25 Saturation 0.518 Diffusivity 0.010
# Step 26 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 115.5672486701109
# Solution converged: 0.0
# Step 26 Saturation 0.547 Diffusivity 0.006
# Step 27 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 124.83981394581872
# Solution converged: 0.0
# Step 27 Saturation 0.574 Diffusivity 0.002
# Step 28 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 124.3651898027602
# Solution converged: 0.0
# Step 28 Saturation 0.584 Diffusivity 0.002
# Step 29 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 124.3651898027602
# Solution converged: 0.0
# Step 29 Saturation 0.584 Diffusivity 0.002
# Step 30 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 122.94431451038336
# Solution converged: 0.0
# Step 30 Saturation 0.604 Diffusivity 0.002
# Step 31 is NOT percolating
# Step 31 Saturation 0.643 Diffusivity 0.000
# Step 32 is NOT percolating
# Step 32 Saturation 0.676 Diffusivity 0.000
# Step 33 is NOT percolating
# Step 33 Saturation 0.699 Diffusivity 0.000
# Step 34 is NOT percolating
# Step 34 Saturation 0.719 Diffusivity 0.000
# Step 35 is NOT percolating
# Step 35 Saturation 0.732 Diffusivity 0.000
# Step 36 is NOT percolating
# Step 36 Saturation 0.742 Diffusivity 0.000
# Step 37 is NOT percolating
# Step 37 Saturation 0.773 Diffusivity 0.000
# Step 38 is NOT percolating
# Step 38 Saturation 0.805 Diffusivity 0.000
# Step 39 is NOT percolating
# Step 39 Saturation 0.820 Diffusivity 0.000
# Step 40 is NOT percolating
# Step 40 Saturation 0.842 Diffusivity 0.000
# Step 41 is NOT percolating
# Step 41 Saturation 0.869 Diffusivity 0.000
# Step 42 is NOT percolating
# Step 42 Saturation 0.893 Diffusivity 0.000
# Step 43 is NOT percolating
# Step 43 Saturation 0.920 Diffusivity 0.000
# Step 44 is NOT percolating
# Step 44 Saturation 0.930 Diffusivity 0.000
# Step 45 is NOT percolating
# Step 45 Saturation 0.945 Diffusivity 0.000
# Step 46 is NOT percolating
# Step 46 Saturation 0.953 Diffusivity 0.000
# Step 47 is NOT percolating
# Step 47 Saturation 0.977 Diffusivity 0.000
# Step 48 is NOT percolating
# Step 48 Saturation 1.000 Diffusivity 0.000
# Step 49 is NOT percolating
# Step 49 Saturation 1.000 Diffusivity 0.000
# Step 50 is NOT percolating
# Step 50 Saturation 1.000 Diffusivity 0.000
# ************************************************************
# Running Sim with Net Size = 8 num points 51
# ************************************************************
# Step 0 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 91.57807439461587
# Solution converged: 0.0
# Step 0 Saturation 0.000 Diffusivity 0.101
# Step 1 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 91.57807439461587
# Solution converged: 0.0
# Step 1 Saturation 0.000 Diffusivity 0.101
# Step 2 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 91.84699013336756
# Solution converged: 0.0
# Step 2 Saturation 0.006 Diffusivity 0.101
# Step 3 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 92.03369969417199
# Solution converged: 0.0
# Step 3 Saturation 0.010 Diffusivity 0.100
# Step 4 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 94.07940489829234
# Solution converged: 0.0
# Step 4 Saturation 0.029 Diffusivity 0.096
# Step 5 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 98.16570104214115
# Solution converged: 0.0
# Step 5 Saturation 0.057 Diffusivity 0.088
# Step 6 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 99.23130453437967
# Solution converged: 0.0
# Step 6 Saturation 0.080 Diffusivity 0.085
# Step 7 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 99.85906104267994
# Solution converged: 0.0
# Step 7 Saturation 0.082 Diffusivity 0.083
# Step 8 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 98.39497370017115
# Solution converged: 0.0
# Step 8 Saturation 0.104 Diffusivity 0.078
# Step 9 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 100.02065765893902
# Solution converged: 0.0
# Step 9 Saturation 0.143 Diffusivity 0.068
# Step 10 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 100.43232468300836
# Solution converged: 0.0
# Step 10 Saturation 0.182 Diffusivity 0.062
# Step 11 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 101.99396352200708
# Solution converged: 0.0
# Step 11 Saturation 0.217 Diffusivity 0.053
# Step 12 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 102.53715443686553
# ...
# Running ReactiveTransport
# Tolerance not met: 100.13917152079134
# Solution converged: 0.0
# Step 15 Saturation 0.334 Diffusivity 0.034
# Step 16 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 100.13917152079134
# Solution converged: 0.0
# Step 16 Saturation 0.334 Diffusivity 0.034
# Step 17 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 100.13917152079134
# Solution converged: 0.0
# Step 17 Saturation 0.336 Diffusivity 0.034
# Step 18 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 100.09926131828004
# Solution converged: 0.0
# Step 18 Saturation 0.346 Diffusivity 0.034
# Step 19 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 98.61890038680733
# Solution converged: 0.0
# Step 19 Saturation 0.352 Diffusivity 0.033
# Step 20 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 97.26616165563742
# Solution converged: 0.0
# Step 20 Saturation 0.363 Diffusivity 0.032
# Step 21 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 97.27129344229596
# Solution converged: 0.0
# Step 21 Saturation 0.371 Diffusivity 0.031
# Step 22 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 103.54922789300754
# Solution converged: 0.0
# Step 22 Saturation 0.389 Diffusivity 0.027
# Step 23 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 109.53474083869222
# Solution converged: 0.0
# Step 23 Saturation 0.416 Diffusivity 0.023
# Step 24 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 113.13954887831635
# Solution converged: 0.0
# Step 24 Saturation 0.445 Diffusivity 0.021
# Step 25 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 115.00727112067803
# Solution converged: 0.0
# Step 25 Saturation 0.467 Diffusivity 0.018
# Step 26 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 113.05656388257611
# Solution converged: 0.0
# Step 26 Saturation 0.488 Diffusivity 0.016
# Step 27 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 111.47452945255387
# Solution converged: 0.0
# Step 27 Saturation 0.496 Diffusivity 0.015
# Step 28 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 106.55920742712443
# Solution converged: 0.0
# Step 28 Saturation 0.531 Diffusivity 0.014
# Step 29 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 113.14614106999392
# Solution converged: 0.0
# Step 29 Saturation 0.549 Diffusivity 0.011
# Step 30 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 116.80662569762256
# Solution converged: 0.0
# Step 30 Saturation 0.568 Diffusivity 0.010
# Step 31 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 123.46452781594122
# Solution converged: 0.0
# Step 31 Saturation 0.584 Diffusivity 0.007
# Step 32 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 119.53457768303105
# Solution converged: 0.0
# Step 32 Saturation 0.605 Diffusivity 0.004
# Step 33 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 116.32923456287386
# Solution converged: 0.0
# Step 33 Saturation 0.633 Diffusivity 0.004
# Step 34 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 115.4934429663516
# Solution converged: 0.0
# Step 34 Saturation 0.648 Diffusivity 0.004
# Step 35 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 112.55567496926668
# Solution converged: 0.0
# Step 35 Saturation 0.670 Diffusivity 0.004
# Step 36 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 109.2088685497663
# Solution converged: 0.0
# Step 36 Saturation 0.701 Diffusivity 0.004
# Step 37 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 106.61445870217212
# Solution converged: 0.0
# Step 37 Saturation 0.730 Diffusivity 0.004
# Step 38 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 100.83819835227285
# Solution converged: 0.0
# Step 38 Saturation 0.764 Diffusivity 0.003
# Step 39 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 87.03288238929095
# Solution converged: 0.0
# Step 39 Saturation 0.795 Diffusivity 0.002
# Step 40 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 86.66986377128245
# Solution converged: 0.0
# Step 40 Saturation 0.814 Diffusivity 0.002
# Step 41 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 95.76893144258642
# Solution converged: 0.0
# Step 41 Saturation 0.840 Diffusivity 0.002
# Step 42 is NOT percolating
# Step 42 Saturation 0.865 Diffusivity 0.000
# Step 43 is NOT percolating
# Step 43 Saturation 0.898 Diffusivity 0.000
# Step 44 is NOT percolating
# Step 44 Saturation 0.932 Diffusivity 0.000
# Step 45 is NOT percolating
# Step 45 Saturation 0.953 Diffusivity 0.000
# Step 46 is NOT percolating
# Step 46 Saturation 0.967 Diffusivity 0.000
# Step 47 is NOT percolating
# Step 47 Saturation 0.986 Diffusivity 0.000
# Step 48 is NOT percolating
# Step 48 Saturation 1.000 Diffusivity 0.000
# Step 49 is NOT percolating
# Step 49 Saturation 1.000 Diffusivity 0.000
# Step 50 is NOT percolating
# Step 50 Saturation 1.000 Diffusivity 0.000
# ************************************************************
# Running Sim with Net Size = 8 num points 51
# ************************************************************
# Step 0 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 93.32148739659141
# Solution converged: 0.0
# Step 0 Saturation 0.000 Diffusivity 0.092
# Step 1 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 93.32148739659141
# Solution converged: 0.0
# Step 1 Saturation 0.000 Diffusivity 0.092
# Step 2 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 93.8765988180972
# Solution converged: 0.0
# Step 2 Saturation 0.006 Diffusivity 0.091
# Step 3 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 94.38856720441397
# Solution converged: 0.0
# Step 3 Saturation 0.014 Diffusivity 0.090
# Step 4 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 94.38856720441397
# Solution converged: 0.0
# Step 4 Saturation 0.014 Diffusivity 0.090
# Step 5 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 97.06207287627504
# Solution converged: 0.0
# Step 5 Saturation 0.041 Diffusivity 0.084
# Step 6 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 97.0534396509756
# Solution converged: 0.0
# Step 6 Saturation 0.082 Diffusivity 0.075
# Step 7 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 95.51490073591751
# Solution converged: 0.0
# Step 7 Saturation 0.121 Diffusivity 0.069
# Step 8 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 95.91578262437326
# Solution converged: 0.0
# Step 8 Saturation 0.146 Diffusivity 0.063
# Step 9 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 94.3908125228253
# Solution converged: 0.0
# Step 9 Saturation 0.186 Diffusivity 0.056
# Step 10 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 89.90077348008859
# Solution converged: 0.0
# Step 10 Saturation 0.225 Diffusivity 0.048
# Step 11 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 88.42269226959229
# Solution converged: 0.0
# Step 11 Saturation 0.264 Diffusivity 0.040
# Step 12 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 84.62988617483151
# Solution converged: 0.0
# Step 12 Saturation 0.305 Diffusivity 0.028
# Step 13 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 80.76877633466466
# Solution converged: 0.0
# Step 13 Saturation 0.342 Diffusivity 0.020
# Step 14 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 82.16195931661677
# Solution converged: 0.0
# Step 14 Saturation 0.371 Diffusivity 0.019
# Step 15 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 80.76918813242716
# Solution converged: 0.0
# Step 15 Saturation 0.398 Diffusivity 0.019
# Step 16 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 80.39150594632773
# Solution converged: 0.0
# Step 16 Saturation 0.408 Diffusivity 0.019
# Step 17 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 75.3091253412972
# Solution converged: 0.0
# Step 17 Saturation 0.434 Diffusivity 0.016
# Step 18 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 78.46748792234811
# Solution converged: 0.0
# Step 18 Saturation 0.463 Diffusivity 0.014
# Step 19 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 81.4588057430635
# Solution converged: 0.0
# Step 19 Saturation 0.480 Diffusivity 0.011
# Step 20 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 82.64026756040357
# Solution converged: 0.0
# Step 20 Saturation 0.498 Diffusivity 0.010
# Step 21 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 82.16931863218512
# Solution converged: 0.0
# Step 21 Saturation 0.514 Diffusivity 0.009
# Step 22 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 80.74512625834886
# Solution converged: 0.0
# Step 22 Saturation 0.521 Diffusivity 0.009
# Step 23 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 80.03493160008361
# Solution converged: 0.0
# Step 23 Saturation 0.553 Diffusivity 0.009
# Step 24 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 80.78409580393028
# Solution converged: 0.0
# Step 24 Saturation 0.584 Diffusivity 0.006
# Step 25 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 80.50492221995998
# Solution converged: 0.0
# Step 25 Saturation 0.615 Diffusivity 0.006
# Step 26 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 88.94028998834443
# Solution converged: 0.0
# Step 26 Saturation 0.654 Diffusivity 0.005
# Step 27 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 89.7284220823498
# Solution converged: 0.0
# Step 27 Saturation 0.682 Diffusivity 0.005
# Step 28 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 90.28304456790647
# Solution converged: 0.0
# Step 28 Saturation 0.693 Diffusivity 0.005
# Step 29 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 87.01630817617367
# Solution converged: 0.0
# Step 29 Saturation 0.715 Diffusivity 0.004
# Step 30 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 95.78792265143564
# Solution converged: 0.0
# Step 30 Saturation 0.756 Diffusivity 0.000
# Step 31 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 89.55363774687177
# Solution converged: 0.0
# Step 31 Saturation 0.773 Diffusivity 0.000
# Step 32 is percolating
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Running ReactiveTransport
# Tolerance not met: 83.20179893034675
# Solution converged: 0.0
# Step 32 Saturation 0.797 Diffusivity 0.000
# Step 33 is NOT percolating
# Step 33 Saturation 0.812 Diffusivity 0.000
# Step 34 is NOT percolating
# Step 34 Saturation 0.818 Diffusivity 0.000
# Step 35 is NOT percolating
# Step 35 Saturation 0.828 Diffusivity 0.000
# Step 36 is NOT percolating
# Step 36 Saturation 0.838 Diffusivity 0.000
# Step 37 is NOT percolating
# Step 37 Saturation 0.855 Diffusivity 0.000
# Step 38 is NOT percolating
# Step 38 Saturation 0.877 Diffusivity 0.000
# Step 39 is NOT percolating
# Step 39 Saturation 0.881 Diffusivity 0.000
# Step 40 is NOT percolating
# Step 40 Saturation 0.881 Diffusivity 0.000
# Step 41 is NOT percolating
# Step 41 Saturation 0.893 Diffusivity 0.000
# Step 42 is NOT percolating
# Step 42 Saturation 0.914 Diffusivity 0.000
# Step 43 is NOT percolating
# Step 43 Saturation 0.924 Diffusivity 0.000
# Step 44 is NOT percolating
# Step 44 Saturation 0.947 Diffusivity 0.000
# Step 45 is NOT percolating
# Step 45 Saturation 0.955 Diffusivity 0.000
# Step 46 is NOT percolating
# Step 46 Saturation 0.977 Diffusivity 0.000
# Step 47 is NOT percolating
# Step 47 Saturation 0.990 Diffusivity 0.000
# Step 48 is NOT percolating
# Step 48 Saturation 1.000 Diffusivity 0.000
# Step 49 is NOT percolating
# Step 49 Saturation 1.000 Diffusivity 0.000
# Step 50 is NOT percolating
# Step 50 Saturation 1.000 Diffusivity 0.000

# %%
x_values = np.asarray(x_values).flatten()
y_values = np.asarray(y_values).flatten()
plt.figure()
from matplotlib.font_manager import FontProperties
fontP = FontProperties()
fontP.set_size('small')

wu_average_x_values = [0.004, 0.021, 0.052, 0.081, 0.129, 0.162, 0.186, 0.219, 0.261,
                       0.286, 0.324, 0.363, 0.42, 0.478, 0.531, 0.586, 0.64, 0.698, 0.747, 0.802]
wu_average_y_values = [0.118, 0.113, 0.105, 0.096, 0.085, 0.078, 0.07, 0.062, 0.054, 0.049, 0.04,
                       0.033, 0.027, 0.02, 0.012, 0.006, 0.003, 0.002, 0.002, 0.002]

p1, = plt.plot(x_values, y_values, 'ko')
p2, = plt.plot(wu_average_x_values, wu_average_y_values, 'ro')
plt.title('normalized diffusivity versus saturation')
plt.xlabel('saturation')
plt.ylabel(r'$\frac{D_e}{D_b}$')
#plt.ylim([0, .15])
plt.xlim([0, 1])
plt.legend([p1, p2],
                   [r'$\frac{D_e}{D_b} = f(\epsilon, \phi)g(s, \phi)$' + '\n' + r'$X = 1.8$' +
                   '\n' + r'$Z_t = 2.0$' + '\n' + r'$Z_i = 4.0$' + '\n' + r'$\beta = 1.0$' + '\n' + r'$n = 14$', "Wu's results"])

plt.show()

# %% [markdown]
# And finally extract the g(S) function for relative diffusivity.

# %%
plt.figure()
normalize_factor = max(y_values)
g_values = y_values / normalize_factor

wu_saturation = [0.004, 0.066, 0.0930, .119, 0.14, 0.175, 0.209, 0.24, 0.282, 0.32, 0.371, 0.413,
                 0.464, 0.517, 0.605, 0.672, 0.761, 0.831, 0.898, 0.948, 0.996]
wu_g_values = [0.986, 0.838, 0.758, 0.701, 0.651, 0.576, 0.516, 0.456, 0.39, 0.335, 0.268, 0.221,
               0.171, 0.111, 0.067, 0.04, 0.019, 0.007, 0.003, 0.003, 0.003]

p1, = plt.plot(x_values, g_values, 'ko')
p2, = plt.plot(wu_saturation, wu_g_values, 'ro')
plt.title('g(s) versus saturation')
plt.xlabel('saturation')
plt.ylabel('g(s)')
plt.legend([p1, p2],
                   ["our values", "Wu's values (fitted curve)"], loc='center left', bbox_to_anchor=(1, 0.5), prop = fontP)
plt.show()
